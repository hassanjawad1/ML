# %% [markdown]
# ###
# Encoding

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# #### use sk learn and encode time

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder

# %% [markdown]
# ####
# - Label encoder

# %%
le= LabelEncoder()
df['encoded time']= le.fit_transform(df['time'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  encoded time
# 0       16.99  1.01  Female     No  Sun  Dinner     2             0
# 1       10.34  1.66    Male     No  Sun  Dinner     3             0
# 2       21.01  3.50    Male     No  Sun  Dinner     3             0
# 3       23.68  3.31    Male     No  Sun  Dinner     2             0
# 4       24.59  3.61  Female     No  Sun  Dinner     4             0

# %%
df['encoded time'].value_counts()
# Out:
# 0    176
# 1     68
# Name: encoded time, dtype: int64

# %% [markdown]
# ####
# - Ordinal encoder

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
oe = OrdinalEncoder(categories=[['Thur', 'Fri', 'Sat', 'Sun']])
df['encoded day']= oe.fit_transform(df[['day']])
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  encoded time  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             0
# 1       10.34  1.66    Male     No  Sun  Dinner     3             0
# 2       21.01  3.50    Male     No  Sun  Dinner     3             0
# 3       23.68  3.31    Male     No  Sun  Dinner     2             0
# 4       24.59  3.61  Female     No  Sun  Dinner     4             0
#
#    encoded day
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          3.0

# %%
df['encoded day'].value_counts()
# Out:
# 2.0    87
# 3.0    76
# 0.0    62
# 1.0    19
# Name: encoded day, dtype: int64

# %% [markdown]
# ###
# - One hot encoder

# %%
titanic= sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic = sns.load_dataset('titanic')

onehot_encoder = OneHotEncoder(sparse=False)
embarked_onehot = onehot_encoder.fit_transform(titanic[['embarked']])
embarked_onehot_df = pd.DataFrame(embarked_onehot, columns=onehot_encoder.get_feature_names_out(['embarked']))
titanic = pd.concat([titanic.reset_index(drop=True), embarked_onehot_df.reset_index(drop=True)], axis=1)
titanic.head()
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  embarked_C  embarked_Q  \
# 0    man        True  NaN  Southampton    no  False         0.0         0.0
# 1  woman       False    C    Cherbourg   yes  False         1.0         0.0
# 2  woman       False  NaN  Southampton   yes   True         0.0         0.0
# 3  woman       False    C  Southampton   yes  False         0.0         0.0
# 4    man        True  NaN  Southampton    no   True         0.0         0.0
#
#    embarked_S  embarked_nan
# 0         1.0           0.0
# 1         0.0           0.0
# 2         1.0           0.0
# 3         1.0           0.0
# 4         1.0           0.0

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %pip install category_encoders
from category_encoders import BinaryEncoder
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      -------------------------------------- 81.9/81.9 kB 507.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.24.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.10.1)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.1-cp311-cp311-win_amd64.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 566.5 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.5.3)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ------------------------------------ 233.9/233.9 kB 841.0 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\roaming\python\python311\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python311\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\roaming\python\python311\site-packages (from statsmodels>=0.9.0->category_encoders) (23.0)
# Installing collected packages: patsy, statsmodels, category_encoders
# Successfully installed category_encoders-2.6.3 patsy-0.5.6 statsmodels-0.14.1
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting category_encodersNote: you may need to restart the kernel to use updated packages.
#
#   Using cached category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.24.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\appdata\roaming\python\python311\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python311\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\roaming\python\python311\site-packages (from statsmodels>=0.9.0->category_encoders) (23.0)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
from category_encoders import BinaryEncoder
binary = BinaryEncoder()
df_binary = binary.fit_transform(df['day'])
df_binary
# Out:
#      day_0  day_1  day_2
# 0        0      0      1
# 1        0      0      1
# 2        0      0      1
# 3        0      0      1
# 4        0      0      1
# ..     ...    ...    ...
# 239      0      1      0
# 240      0      1      0
# 241      0      1      0
# 242      0      1      0
# 243      0      1      1
#
# [244 rows x 3 columns]
